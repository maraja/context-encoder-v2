# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.3.3
# !pip install stop_words
# !pip install symspellpy
# !pip install language_detector 
# !pip install cached_property
# !pip install sentencepiece
# !pip install config
# !pip install umap
# !pip install sentence-transformers==0.4.1
# !pip install nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# Requirement already satisfied: transformers==4.3.3 in /usr/local/lib/python3.7/dist-packages (4.3.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (1.19.5)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (0.0.46)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (2.23.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (4.62.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (4.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (1.15.0)
# Requirement already satisfied: stop_words in /usr/local/lib/python3.7/dist-packages (2018.7.23)
# Requirement already satisfied: symspellpy in /usr/local/lib/python3.7/dist-packages (6.7.0)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.7/dist-packages (from symspellpy) (1.19.5)
# Requirement already satisfied: language_detector in /usr/local/lib/python3.7/dist-packages (5.0.2)
# Requirement already satisfied: cached_property in /usr/local/lib/python3.7/dist-packages (1.5.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)
# Requirement already satisfied: config in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: umap in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: sentence-transformers==0.4.1 in /usr/local/lib/python3.7/dist-packages (0.4.1)
# Requirement already satisfied: transformers<5.0.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (4.3.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.4.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.9.0+cu102)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (0.1.96)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (4.62.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (0.22.2.post1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (3.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers==0.4.1) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (21.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (4.8.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (0.0.46)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers==0.4.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (7.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import tensorflow, sentence_transformers, transformers
tensorflow.__version__, sentence_transformers.__version__, transformers.__version__
# Out:
# ('2.6.0', '0.4.1', '4.3.3')

# %%
root_path = "/content/drive/MyDrive/SCHOOL/PhD/Code/context-encoder-v2"
import sys, os
import config

config.root_path = os.path.abspath(root_path)
sys.path.insert(0, config.root_path)

# %%
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from src.encoders.context_encoder_ldabert_2 import ContextEncoderSimple
from src.dataset.ldabert_2 import LDABERT2Dataset

from tensorflow.python import keras
import toml
import json
import pandas as pd
import numpy as np
from utils.experiments import get_experiments_json, get_experiments, save_results
# Out:
# Downloading:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/409 [00:00<?, ?B/s]

# %% [markdown]
# ## Experiment

# %%
experiments_config = get_experiments_json('ldabert2_simple_test')
experiments_config_df = pd.DataFrame.from_dict(experiments_config)
experiments_config_df
# Out:
#   bert_type dataset_type  final_dropout  ...  augment_pct  bert_trainable  epochs
# 0   ldabert     clinical            0.5  ...            1           False    1000
# 1   ldabert         wiki            0.5  ...            1           False    1000
# 2   ldabert      fiction            0.5  ...            1           False    1000
#
# [3 rows x 10 columns]

# %%
experiments_config_df.to_csv(r'../models/experiment.csv', header=None, index=None, sep=' ', mode='a')

# %%
def get_random_hash(k):
  import random, string
  x = ''.join(random.choices(string.ascii_letters + string.digits, k=k))
  return x

# %%
# just do clinical for now
for experiment in experiments_config[:1]:
    dataset_type = experiment['dataset_type']
    final_dropout = experiment['final_dropout']
    dense_neurons = experiment['dense_neurons']
    pct_data = experiment['pct_data']
    augment_pct = experiment['augment_pct']
    gamma = experiment['gamma']
    max_sentence_length = experiment['max_sentence_length']
    bert_trainable = experiment['bert_trainable']
    epochs = 200 # experiment['epochs']
    BATCH_SIZE = 8
    print("params:", experiment)
    random_hash = get_random_hash(5)
    experiment['epochs'] = epochs
    
    # init model
    print("initializing model...")
    model = ContextEncoderSimple(final_dropout=final_dropout,
                            dense_neurons=dense_neurons,
                          gamma=gamma,
                          max_sentence_length=max_sentence_length,
                           bert_trainable=bert_trainable)
    
    # print("number of params: ", sum([np.prod(keras.get_value(w).shape) for w in model.trainable_weights]))
    
    # init dataset
    print("initializing dataset...")
    dataset = LDABERT2Dataset(dataset_type=dataset_type,
                            pct_data=pct_data,
                          max_seq_length=max_sentence_length,
                            max_segment_length=5,
                            augment_pct=augment_pct,
                            split="train")
    
    # process dataset
    print("processing dataset...")
    sentences, tokenized_sentences, labels = dataset.process()

    vectors_filename = '{}_{}.pkl'.format(dataset.pct_data, dataset.augment_pct)

    saved_vectors, saved_labels, saved_sentences, saved_tokenized_sentences = dataset.get_saved_vectors("train", dataset.dataset_type, vectors_filename)

    if len(saved_vectors) == 0:
        saved_vectors, saved_labels, saved_sentences, saved_tokenized_sentences = dataset.create_vectors("train", dataset.dataset_type, vectors_filename)

    left_input, mid_input, right_input = dataset.format_sentences_tri_input_plus(saved_tokenized_sentences)
    lda_left_input, lda_mid_input, lda_right_input = dataset.format_sentences_tri_input(saved_vectors)

    # get class weight
    neg, pos = np.bincount(labels.flatten())
    initial_bias = np.log([pos/neg])
    
    total=len(labels)
    weight_for_0 = (1 / neg)*(total)/2.0 
    weight_for_1 = (1 / pos)*(total)/2.0

    class_weight = {0: weight_for_0, 1: weight_for_1}
    print("class weight", class_weight)
    
    # create checkpoint path
    checkpoint_filepath = '{}/models/LDABERT2/simple/{}-{}-{}-pct-{}-aug_{}/no-finetune/checkpoint.ckpt'.format(
                            config.root_path,
                            dataset.dataset_type,                    
                            len(saved_sentences), 
                            dataset.pct_data,
                            dataset.augment_pct,
                            random_hash)
    
    # # continue training
    # random_hash = 'nH75d'
    # checkpoint_filepath = '{}/models/LDABERT2/simple/clinical-15051-1-pct-1-aug_{}/no-finetune/checkpoint.ckpt'.format(
    #     config.root_path,
    #     random_hash
    # )

    # model_filepath = "/".join(checkpoint_filepath.split("/")[:-1]) + "/model.h5"
    print(checkpoint_filepath)
    
    # get callbacks ready.
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        save_best_only=True,
        mode="auto",
        save_freq="epoch")

    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', 
        verbose=1,
        patience=10,
        mode='max',
        restore_best_weights=True)
    
    log_path = '{}/models/LDABERT2/simple/{}-{}-{}-pct-{}-aug_{}/no-finetune/training.log'.format(
                            config.root_path,
                            dataset.dataset_type,                    
                            len(saved_sentences), 
                            dataset.pct_data,
                            dataset.augment_pct,
                            random_hash)
    
    csv_logger = tf.keras.callbacks.CSVLogger(log_path, separator=",", append=False)

    callbacks = [
    #     early_stopping,
        model_checkpoint_callback,
        csv_logger
    ]
    
    # compiling model
    print("compiling the model...")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[
                      keras.metrics.BinaryAccuracy(name='accuracy')
                  ])
    
    try:
        model.load_weights(checkpoint_filepath)
        print("model loaded.")
    except:
        print("No checkpoint available.")
    
    print("starting the training process...")
    history = model.fit([
                            left_input, mid_input, right_input, 
                            lda_left_input, lda_mid_input, lda_right_input
                        ], 
                        tf.convert_to_tensor(saved_labels), 
                        epochs=epochs,
                        validation_split=0.25,
                        batch_size=BATCH_SIZE,
                        verbose=1, 
                        class_weight=class_weight,
                        callbacks=callbacks)

    # assigning history to experiment object for saving.
    experiment["history"] = history.history
    experiment["hash"] = random_hash
    
    print("saving results...")
    save_results(experiment)
# Out:
# params: {'bert_type': 'ldabert', 'dataset_type': 'clinical', 'final_dropout': 0.5, 'dense_neurons': 128, 'max_sentence_length': 128, 'gamma': 15, 'pct_data': 1, 'augment_pct': 1, 'bert_trainable': False, 'epochs': 200}
# initializing model...
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# initializing dataset...
# processing dataset...
# class weight {0: 0.6363521055301877, 1: 2.3334883720930235}
# /content/drive/MyDrive/SCHOOL/PhD/Code/context-encoder-v2/models/LDABERT2/simple/clinical-15051-1-pct-1-aug_ngJYP/no-finetune/checkpoint.ckpt
# compiling the model...
# No checkpoint available.
# starting the training process...
# Epoch 1/200
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 1411/1411 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.5442WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 1411/1411 [==============================] - 506s 348ms/step - loss: 0.7042 - accuracy: 0.5442 - val_loss: 0.7018 - val_accuracy: 0.5606
# Epoch 2/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.6608 - accuracy: 0.5712 - val_loss: 0.6053 - val_accuracy: 0.5854
# Epoch 3/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.6294 - accuracy: 0.5980 - val_loss: 0.6743 - val_accuracy: 0.6047
# Epoch 4/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.6181 - accuracy: 0.6094 - val_loss: 0.6746 - val_accuracy: 0.6135
# Epoch 5/200
# 1411/1411 [==============================] - 487s 346ms/step - loss: 0.5992 - accuracy: 0.6174 - val_loss: 0.4846 - val_accuracy: 0.6260
# Epoch 6/200
# 1411/1411 [==============================] - 487s 346ms/step - loss: 0.5958 - accuracy: 0.6324 - val_loss: 0.5595 - val_accuracy: 0.6371
# Epoch 7/200
# 1411/1411 [==============================] - 487s 346ms/step - loss: 0.5806 - accuracy: 0.6408 - val_loss: 0.4374 - val_accuracy: 0.6463
# Epoch 8/200
# 1411/1411 [==============================] - 487s 346ms/step - loss: 0.5784 - accuracy: 0.6511 - val_loss: 0.5222 - val_accuracy: 0.6545
# Epoch 9/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5767 - accuracy: 0.6574 - val_loss: 0.5017 - val_accuracy: 0.6604
# Epoch 10/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5662 - accuracy: 0.6634 - val_loss: 0.5196 - val_accuracy: 0.6658
# Epoch 11/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5611 - accuracy: 0.6680 - val_loss: 0.5112 - val_accuracy: 0.6703
# Epoch 12/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5608 - accuracy: 0.6722 - val_loss: 0.5330 - val_accuracy: 0.6738
# Epoch 13/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5516 - accuracy: 0.6754 - val_loss: 0.5164 - val_accuracy: 0.6771
# Epoch 14/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5459 - accuracy: 0.6786 - val_loss: 0.4887 - val_accuracy: 0.6803
# Epoch 15/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5458 - accuracy: 0.6818 - val_loss: 0.4438 - val_accuracy: 0.6835
# Epoch 16/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5477 - accuracy: 0.6851 - val_loss: 0.6169 - val_accuracy: 0.6857
# Epoch 17/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5379 - accuracy: 0.6863 - val_loss: 0.4487 - val_accuracy: 0.6879
# Epoch 18/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5336 - accuracy: 0.6894 - val_loss: 0.5042 - val_accuracy: 0.6907
# Epoch 19/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5353 - accuracy: 0.6919 - val_loss: 0.4902 - val_accuracy: 0.6931
# Epoch 20/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5311 - accuracy: 0.6942 - val_loss: 0.4414 - val_accuracy: 0.6953
# Epoch 21/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5315 - accuracy: 0.6965 - val_loss: 0.4482 - val_accuracy: 0.6977
# Epoch 22/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5276 - accuracy: 0.6988 - val_loss: 0.4305 - val_accuracy: 0.7000
# Epoch 23/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5278 - accuracy: 0.7011 - val_loss: 0.4857 - val_accuracy: 0.7020
# Epoch 24/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5278 - accuracy: 0.7027 - val_loss: 0.5289 - val_accuracy: 0.7034
# Epoch 25/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5275 - accuracy: 0.7039 - val_loss: 0.3946 - val_accuracy: 0.7049
# Epoch 26/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5226 - accuracy: 0.7059 - val_loss: 0.5698 - val_accuracy: 0.7063
# Epoch 27/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5171 - accuracy: 0.7067 - val_loss: 0.4217 - val_accuracy: 0.7077
# Epoch 28/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5170 - accuracy: 0.7085 - val_loss: 0.4595 - val_accuracy: 0.7092
# Epoch 29/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5171 - accuracy: 0.7100 - val_loss: 0.4844 - val_accuracy: 0.7106
# Epoch 30/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5144 - accuracy: 0.7112 - val_loss: 0.5231 - val_accuracy: 0.7116
# Epoch 31/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5162 - accuracy: 0.7121 - val_loss: 0.4548 - val_accuracy: 0.7128
# Epoch 32/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5137 - accuracy: 0.7135 - val_loss: 0.3948 - val_accuracy: 0.7142
# Epoch 33/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5123 - accuracy: 0.7149 - val_loss: 0.4251 - val_accuracy: 0.7155
# Epoch 34/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5110 - accuracy: 0.7162 - val_loss: 0.5131 - val_accuracy: 0.7165
# Epoch 35/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5067 - accuracy: 0.7168 - val_loss: 0.4599 - val_accuracy: 0.7174
# Epoch 36/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5028 - accuracy: 0.7180 - val_loss: 0.3914 - val_accuracy: 0.7186
# Epoch 37/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5032 - accuracy: 0.7193 - val_loss: 0.5072 - val_accuracy: 0.7197
# Epoch 38/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.5030 - accuracy: 0.7202 - val_loss: 0.5543 - val_accuracy: 0.7205
# Epoch 39/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4968 - accuracy: 0.7208 - val_loss: 0.4233 - val_accuracy: 0.7214
# Epoch 40/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4950 - accuracy: 0.7220 - val_loss: 0.4000 - val_accuracy: 0.7227
# Epoch 41/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4963 - accuracy: 0.7231 - val_loss: 0.4303 - val_accuracy: 0.7237
# Epoch 42/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4987 - accuracy: 0.7242 - val_loss: 0.4263 - val_accuracy: 0.7246
# Epoch 43/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4954 - accuracy: 0.7251 - val_loss: 0.4524 - val_accuracy: 0.7255
# Epoch 44/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4970 - accuracy: 0.7258 - val_loss: 0.4669 - val_accuracy: 0.7262
# Epoch 45/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4937 - accuracy: 0.7265 - val_loss: 0.4150 - val_accuracy: 0.7270
# Epoch 46/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4873 - accuracy: 0.7275 - val_loss: 0.4742 - val_accuracy: 0.7279
# Epoch 47/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4900 - accuracy: 0.7283 - val_loss: 0.4139 - val_accuracy: 0.7288
# Epoch 48/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4896 - accuracy: 0.7291 - val_loss: 0.4356 - val_accuracy: 0.7296
# Epoch 49/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4900 - accuracy: 0.7300 - val_loss: 0.4059 - val_accuracy: 0.7304
# Epoch 50/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4850 - accuracy: 0.7309 - val_loss: 0.5067 - val_accuracy: 0.7312
# Epoch 51/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4866 - accuracy: 0.7314 - val_loss: 0.5549 - val_accuracy: 0.7316
# Epoch 52/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4874 - accuracy: 0.7317 - val_loss: 0.4405 - val_accuracy: 0.7320
# Epoch 53/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4898 - accuracy: 0.7323 - val_loss: 0.4573 - val_accuracy: 0.7326
# Epoch 54/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4868 - accuracy: 0.7329 - val_loss: 0.3592 - val_accuracy: 0.7333
# Epoch 55/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4852 - accuracy: 0.7338 - val_loss: 0.4018 - val_accuracy: 0.7342
# Epoch 56/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4824 - accuracy: 0.7346 - val_loss: 0.4206 - val_accuracy: 0.7350
# Epoch 57/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4846 - accuracy: 0.7352 - val_loss: 0.4040 - val_accuracy: 0.7356
# Epoch 58/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4791 - accuracy: 0.7360 - val_loss: 0.3885 - val_accuracy: 0.7364
# Epoch 59/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4758 - accuracy: 0.7367 - val_loss: 0.3734 - val_accuracy: 0.7371
# Epoch 60/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4792 - accuracy: 0.7375 - val_loss: 0.4166 - val_accuracy: 0.7378
# Epoch 61/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4797 - accuracy: 0.7381 - val_loss: 0.3840 - val_accuracy: 0.7384
# Epoch 62/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4770 - accuracy: 0.7388 - val_loss: 0.4016 - val_accuracy: 0.7392
# Epoch 63/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4768 - accuracy: 0.7394 - val_loss: 0.3923 - val_accuracy: 0.7398
# Epoch 64/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4750 - accuracy: 0.7401 - val_loss: 0.3676 - val_accuracy: 0.7404
# Epoch 65/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4739 - accuracy: 0.7408 - val_loss: 0.4487 - val_accuracy: 0.7410
# Epoch 66/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4753 - accuracy: 0.7413 - val_loss: 0.3604 - val_accuracy: 0.7416
# Epoch 67/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4720 - accuracy: 0.7419 - val_loss: 0.3375 - val_accuracy: 0.7423
# Epoch 68/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4717 - accuracy: 0.7426 - val_loss: 0.4170 - val_accuracy: 0.7429
# Epoch 69/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4765 - accuracy: 0.7431 - val_loss: 0.3518 - val_accuracy: 0.7434
# Epoch 70/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4746 - accuracy: 0.7438 - val_loss: 0.3943 - val_accuracy: 0.7440
# Epoch 71/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4678 - accuracy: 0.7443 - val_loss: 0.3573 - val_accuracy: 0.7446
# Epoch 72/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4705 - accuracy: 0.7450 - val_loss: 0.4106 - val_accuracy: 0.7452
# Epoch 73/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4731 - accuracy: 0.7454 - val_loss: 0.4038 - val_accuracy: 0.7457
# Epoch 74/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4723 - accuracy: 0.7459 - val_loss: 0.4528 - val_accuracy: 0.7461
# Epoch 75/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4640 - accuracy: 0.7463 - val_loss: 0.3965 - val_accuracy: 0.7465
# Epoch 76/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4634 - accuracy: 0.7468 - val_loss: 0.4348 - val_accuracy: 0.7471
# Epoch 77/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4713 - accuracy: 0.7472 - val_loss: 0.3372 - val_accuracy: 0.7475
# Epoch 78/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4611 - accuracy: 0.7478 - val_loss: 0.4451 - val_accuracy: 0.7480
# Epoch 79/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4582 - accuracy: 0.7482 - val_loss: 0.3521 - val_accuracy: 0.7486
# Epoch 80/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4664 - accuracy: 0.7488 - val_loss: 0.3629 - val_accuracy: 0.7491
# Epoch 81/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4565 - accuracy: 0.7493 - val_loss: 0.3587 - val_accuracy: 0.7496
# Epoch 82/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4643 - accuracy: 0.7499 - val_loss: 0.4299 - val_accuracy: 0.7501
# Epoch 83/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4546 - accuracy: 0.7503 - val_loss: 0.3390 - val_accuracy: 0.7506
# Epoch 84/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4601 - accuracy: 0.7509 - val_loss: 0.4406 - val_accuracy: 0.7511
# Epoch 85/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4646 - accuracy: 0.7512 - val_loss: 0.3872 - val_accuracy: 0.7514
# Epoch 86/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4643 - accuracy: 0.7516 - val_loss: 0.3892 - val_accuracy: 0.7519
# Epoch 87/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4540 - accuracy: 0.7521 - val_loss: 0.4198 - val_accuracy: 0.7523
# Epoch 88/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4575 - accuracy: 0.7525 - val_loss: 0.3355 - val_accuracy: 0.7527
# Epoch 89/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4548 - accuracy: 0.7530 - val_loss: 0.4404 - val_accuracy: 0.7532
# Epoch 90/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4533 - accuracy: 0.7533 - val_loss: 0.4302 - val_accuracy: 0.7535
# Epoch 91/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4537 - accuracy: 0.7537 - val_loss: 0.3523 - val_accuracy: 0.7540
# Epoch 92/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4544 - accuracy: 0.7542 - val_loss: 0.3677 - val_accuracy: 0.7545
# Epoch 93/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4543 - accuracy: 0.7547 - val_loss: 0.3616 - val_accuracy: 0.7549
# Epoch 94/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4572 - accuracy: 0.7551 - val_loss: 0.3477 - val_accuracy: 0.7553
# Epoch 95/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4518 - accuracy: 0.7555 - val_loss: 0.3563 - val_accuracy: 0.7558
# Epoch 96/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4487 - accuracy: 0.7560 - val_loss: 0.3231 - val_accuracy: 0.7563
# Epoch 97/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4477 - accuracy: 0.7565 - val_loss: 0.4926 - val_accuracy: 0.7566
# Epoch 98/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4498 - accuracy: 0.7567 - val_loss: 0.3927 - val_accuracy: 0.7569
# Epoch 99/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4527 - accuracy: 0.7571 - val_loss: 0.3706 - val_accuracy: 0.7573
# Epoch 100/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4529 - accuracy: 0.7575 - val_loss: 0.4541 - val_accuracy: 0.7576
# Epoch 101/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4442 - accuracy: 0.7577 - val_loss: 0.3718 - val_accuracy: 0.7579
# Epoch 102/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4454 - accuracy: 0.7581 - val_loss: 0.3263 - val_accuracy: 0.7584
# Epoch 103/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4409 - accuracy: 0.7586 - val_loss: 0.3695 - val_accuracy: 0.7588
# Epoch 104/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4412 - accuracy: 0.7590 - val_loss: 0.4047 - val_accuracy: 0.7592
# Epoch 105/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4395 - accuracy: 0.7593 - val_loss: 0.4006 - val_accuracy: 0.7595
# Epoch 106/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4452 - accuracy: 0.7597 - val_loss: 0.3223 - val_accuracy: 0.7599
# Epoch 107/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4433 - accuracy: 0.7601 - val_loss: 0.3910 - val_accuracy: 0.7603
# Epoch 108/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4410 - accuracy: 0.7605 - val_loss: 0.3376 - val_accuracy: 0.7607
# Epoch 109/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4416 - accuracy: 0.7609 - val_loss: 0.4078 - val_accuracy: 0.7611
# Epoch 110/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4417 - accuracy: 0.7612 - val_loss: 0.3711 - val_accuracy: 0.7614
# Epoch 111/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4442 - accuracy: 0.7616 - val_loss: 0.4917 - val_accuracy: 0.7617
# Epoch 112/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4372 - accuracy: 0.7618 - val_loss: 0.3915 - val_accuracy: 0.7620
# Epoch 113/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4426 - accuracy: 0.7621 - val_loss: 0.4781 - val_accuracy: 0.7622
# Epoch 114/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4439 - accuracy: 0.7623 - val_loss: 0.4404 - val_accuracy: 0.7624
# Epoch 115/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4362 - accuracy: 0.7626 - val_loss: 0.4045 - val_accuracy: 0.7627
# Epoch 116/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4386 - accuracy: 0.7629 - val_loss: 0.4169 - val_accuracy: 0.7631
# Epoch 117/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4376 - accuracy: 0.7632 - val_loss: 0.3771 - val_accuracy: 0.7634
# Epoch 118/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4348 - accuracy: 0.7635 - val_loss: 0.4102 - val_accuracy: 0.7637
# Epoch 119/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4378 - accuracy: 0.7638 - val_loss: 0.3460 - val_accuracy: 0.7640
# Epoch 120/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4302 - accuracy: 0.7642 - val_loss: 0.3997 - val_accuracy: 0.7643
# Epoch 121/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4376 - accuracy: 0.7644 - val_loss: 0.3405 - val_accuracy: 0.7646
# Epoch 122/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4343 - accuracy: 0.7648 - val_loss: 0.3570 - val_accuracy: 0.7649
# Epoch 123/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4302 - accuracy: 0.7651 - val_loss: 0.3779 - val_accuracy: 0.7653
# Epoch 124/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4340 - accuracy: 0.7654 - val_loss: 0.4081 - val_accuracy: 0.7656
# Epoch 125/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4390 - accuracy: 0.7657 - val_loss: 0.3893 - val_accuracy: 0.7658
# Epoch 126/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4296 - accuracy: 0.7660 - val_loss: 0.3457 - val_accuracy: 0.7662
# Epoch 127/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4330 - accuracy: 0.7663 - val_loss: 0.4264 - val_accuracy: 0.7664
# Epoch 128/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4272 - accuracy: 0.7666 - val_loss: 0.3675 - val_accuracy: 0.7667
# Epoch 129/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4309 - accuracy: 0.7669 - val_loss: 0.3674 - val_accuracy: 0.7670
# Epoch 130/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4256 - accuracy: 0.7672 - val_loss: 0.4176 - val_accuracy: 0.7673
# Epoch 131/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4305 - accuracy: 0.7674 - val_loss: 0.3339 - val_accuracy: 0.7676
# Epoch 132/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4317 - accuracy: 0.7678 - val_loss: 0.3971 - val_accuracy: 0.7679
# Epoch 133/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4291 - accuracy: 0.7680 - val_loss: 0.3830 - val_accuracy: 0.7682
# Epoch 134/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4219 - accuracy: 0.7683 - val_loss: 0.3692 - val_accuracy: 0.7685
# Epoch 135/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4273 - accuracy: 0.7686 - val_loss: 0.3985 - val_accuracy: 0.7687
# Epoch 136/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4278 - accuracy: 0.7689 - val_loss: 0.3219 - val_accuracy: 0.7690
# Epoch 137/200
# 1411/1411 [==============================] - 490s 347ms/step - loss: 0.4261 - accuracy: 0.7692 - val_loss: 0.3391 - val_accuracy: 0.7693
# Epoch 138/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4367 - accuracy: 0.7695 - val_loss: 0.4827 - val_accuracy: 0.7695
# Epoch 139/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4277 - accuracy: 0.7696 - val_loss: 0.3527 - val_accuracy: 0.7698
# Epoch 140/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4232 - accuracy: 0.7699 - val_loss: 0.3644 - val_accuracy: 0.7700
# Epoch 141/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4341 - accuracy: 0.7702 - val_loss: 0.3350 - val_accuracy: 0.7703
# Epoch 142/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4203 - accuracy: 0.7705 - val_loss: 0.3779 - val_accuracy: 0.7706
# Epoch 143/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4207 - accuracy: 0.7707 - val_loss: 0.3917 - val_accuracy: 0.7709
# Epoch 144/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4237 - accuracy: 0.7710 - val_loss: 0.3491 - val_accuracy: 0.7711
# Epoch 145/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4211 - accuracy: 0.7712 - val_loss: 0.3557 - val_accuracy: 0.7714
# Epoch 146/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4227 - accuracy: 0.7715 - val_loss: 0.3288 - val_accuracy: 0.7717
# Epoch 147/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4207 - accuracy: 0.7718 - val_loss: 0.3930 - val_accuracy: 0.7719
# Epoch 148/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4207 - accuracy: 0.7720 - val_loss: 0.4144 - val_accuracy: 0.7722
# Epoch 149/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4174 - accuracy: 0.7723 - val_loss: 0.3638 - val_accuracy: 0.7724
# Epoch 150/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4178 - accuracy: 0.7725 - val_loss: 0.3472 - val_accuracy: 0.7727
# Epoch 151/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4196 - accuracy: 0.7728 - val_loss: 0.3351 - val_accuracy: 0.7729
# Epoch 152/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4209 - accuracy: 0.7731 - val_loss: 0.3981 - val_accuracy: 0.7732
# Epoch 153/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4211 - accuracy: 0.7733 - val_loss: 0.3974 - val_accuracy: 0.7734
# Epoch 154/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4156 - accuracy: 0.7735 - val_loss: 0.3648 - val_accuracy: 0.7736
# Epoch 155/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4158 - accuracy: 0.7738 - val_loss: 0.3776 - val_accuracy: 0.7739
# Epoch 156/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4159 - accuracy: 0.7740 - val_loss: 0.3238 - val_accuracy: 0.7742
# Epoch 157/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4104 - accuracy: 0.7743 - val_loss: 0.3056 - val_accuracy: 0.7745
# Epoch 158/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4262 - accuracy: 0.7746 - val_loss: 0.3804 - val_accuracy: 0.7747
# Epoch 159/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4119 - accuracy: 0.7748 - val_loss: 0.3464 - val_accuracy: 0.7750
# Epoch 160/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4129 - accuracy: 0.7751 - val_loss: 0.3717 - val_accuracy: 0.7752
# Epoch 161/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4101 - accuracy: 0.7753 - val_loss: 0.3516 - val_accuracy: 0.7754
# Epoch 162/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4076 - accuracy: 0.7756 - val_loss: 0.3081 - val_accuracy: 0.7757
# Epoch 163/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4111 - accuracy: 0.7759 - val_loss: 0.3950 - val_accuracy: 0.7760
# Epoch 164/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4066 - accuracy: 0.7761 - val_loss: 0.4403 - val_accuracy: 0.7762
# Epoch 165/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4200 - accuracy: 0.7763 - val_loss: 0.3546 - val_accuracy: 0.7764
# Epoch 166/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4153 - accuracy: 0.7765 - val_loss: 0.3141 - val_accuracy: 0.7766
# Epoch 167/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4125 - accuracy: 0.7768 - val_loss: 0.3183 - val_accuracy: 0.7769
# Epoch 168/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4101 - accuracy: 0.7770 - val_loss: 0.3275 - val_accuracy: 0.7771
# Epoch 169/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4054 - accuracy: 0.7773 - val_loss: 0.3364 - val_accuracy: 0.7774
# Epoch 170/200
# 1411/1411 [==============================] - 488s 346ms/step - loss: 0.4173 - accuracy: 0.7775 - val_loss: 0.3685 - val_accuracy: 0.7776
# Epoch 171/200
# 1411/1411 [==============================] - 489s 346ms/step - loss: 0.4040 - accuracy: 0.7777 - val_loss: 0.4046 - val_accuracy: 0.7778
# Epoch 172/200
# 1411/1411 [==============================] - 489s 347ms/step - loss: 0.4128 - accuracy: 0.7779 - val_loss: 0.2991 - val_accuracy: 0.7780
# Epoch 173/200
#  447/1411 [========>.....................] - ETA: 4:17 - loss: 0.4154 - accuracy: 0.7781

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d7a4aa83693> in <module>()
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined
