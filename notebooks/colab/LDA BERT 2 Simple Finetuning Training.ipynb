# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.3.3
# !pip install stop_words
# !pip install symspellpy
# !pip install language_detector 
# !pip install cached_property
# !pip install sentencepiece
# !pip install config
# !pip install umap
# !pip install sentence-transformers==0.4.1
# !pip install nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# Collecting transformers==4.3.3
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (4.41.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (3.0.12)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 68.9 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 66.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3) (4.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.3.3
# Collecting stop_words
#   Downloading stop-words-2018.7.23.tar.gz (31 kB)
# Building wheels for collected packages: stop-words
#   Building wheel for stop-words (setup.py) ... done
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32911 sha256=db75f5b89e91b98e2b4dc27bfa96faed4c511d570c0876be02519ee9a2c78dd9
#   Stored in directory: /root/.cache/pip/wheels/fb/86/b2/277b10b1ce9f73ce15059bf6975d4547cc4ec3feeb651978e9
# Successfully built stop-words
# Installing collected packages: stop-words
# Successfully installed stop-words-2018.7.23
# Collecting symspellpy
#   Downloading symspellpy-6.7.0-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 9.0 MB/s
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.7/dist-packages (from symspellpy) (1.19.5)
# Installing collected packages: symspellpy
# Successfully installed symspellpy-6.7.0
# Collecting language_detector
#   Downloading language-detector-5.0.2.tar.gz (6.6 kB)
# Building wheels for collected packages: language-detector
#   Building wheel for language-detector (setup.py) ... done
#   Created wheel for language-detector: filename=language_detector-5.0.2-py3-none-any.whl size=7053 sha256=06bcbc91e50a3861568880475b7ec5e0fb072740ccbded8f03c68fffcc3032da
#   Stored in directory: /root/.cache/pip/wheels/12/40/73/a0765d65e793332b79dfe6c34c713e7c0066ea785191b3f50a
# Successfully built language-detector
# Installing collected packages: language-detector
# Successfully installed language-detector-5.0.2
# Requirement already satisfied: cached_property in /usr/local/lib/python3.7/dist-packages (1.5.2)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 8.4 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Collecting config
#   Downloading config-0.5.0.post0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.0.post0
# Collecting umap
#   Downloading umap-0.1.1.tar.gz (3.2 kB)
# Building wheels for collected packages: umap
#   Building wheel for umap (setup.py) ... done
#   Created wheel for umap: filename=umap-0.1.1-py3-none-any.whl size=3566 sha256=86f36ca8a2bac28637ed82c8d20eb49443b22f9a2d4e9abc56cc1eada1b72f5b
#   Stored in directory: /root/.cache/pip/wheels/65/55/85/945cfb3d67373767e4dc3e9629300a926edde52633df4f0efe
# Successfully built umap
# Installing collected packages: umap
# Successfully installed umap-0.1.1
# Collecting sentence-transformers==0.4.1
#   Downloading sentence-transformers-0.4.1.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 2.4 MB/s
# Requirement already satisfied: transformers<5.0.0,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (4.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.9.0+cu102)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (3.2.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers==0.4.1) (0.1.96)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers==0.4.1) (3.7.4.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (0.10.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (0.0.45)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (4.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (21.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers==0.4.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers==0.4.1) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.4.1-py3-none-any.whl size=103051 sha256=0ea0f12431aed4a59b5de4af0d3850a0addf2d6f9aa52e059e0c6406d9717e1c
#   Stored in directory: /root/.cache/pip/wheels/ed/2b/00/349b245f5256ba7a5d874bcb0f1f2dfc8b4b963d80b38626ac
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-0.4.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
root_path = "/content/drive/MyDrive/SCHOOL/PhD/Code/context-encoder-v2"
import sys, os
import config

config.root_path = os.path.abspath(root_path)
sys.path.insert(0, config.root_path)

# %%
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from src.encoders.context_encoder_ldabert_2 import ContextEncoder
from src.dataset.ldabert_2 import LDABERT2Dataset

from tensorflow.python import keras
import toml
import json
import pandas as pd
import numpy as np
from utils.experiments import get_experiments_json, get_experiments, save_results
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=630.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466081.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=409.0, style=ProgressStyle(description_…

# %% [markdown]
# ## Experiment

# %%
experiments_config = get_experiments_json('ldabert2_simple_finetune_test')
experiments_config_df = pd.DataFrame.from_dict(experiments_config)
experiments_config_df
# Out:
#   bert_type dataset_type  final_dropout  ...  augment_pct  bert_trainable  epochs
# 0   ldabert     clinical            0.5  ...            1            True      50
# 1   ldabert         wiki            0.5  ...            1            True      50
# 2   ldabert      fiction            0.5  ...            1            True      50
#
# [3 rows x 10 columns]

# %%
experiments_config_df.to_csv(r'../models/experiment.csv', header=None, index=None, sep=' ', mode='a')

# %%
def get_random_hash(k):
  import random, string
  x = ''.join(random.choices(string.ascii_letters + string.digits, k=k))
  return x

# %%
# just do clinical for now
for experiment in experiments_config[:1]:
    dataset_type = experiment['dataset_type']
    final_dropout = experiment['final_dropout']
    dense_neurons = experiment['dense_neurons']
    pct_data = experiment['pct_data']
    augment_pct = experiment['augment_pct']
    gamma = experiment['gamma']
    max_sentence_length = experiment['max_sentence_length']
    bert_trainable = experiment['bert_trainable']
    epochs = 300 # experiment['epochs']
    BATCH_SIZE = 8
    print("params:", experiment)
    random_hash = get_random_hash(5)
    experiment['epochs'] = epochs
    
    # init model
    print("initializing model...")
    model = ContextEncoder(final_dropout=final_dropout,
                            dense_neurons=dense_neurons,
                          gamma=gamma,
                          max_sentence_length=max_sentence_length,
                           bert_trainable=bert_trainable)
    
    # print("number of params: ", sum([np.prod(keras.get_value(w).shape) for w in model.trainable_weights]))
    
    # init dataset
    print("initializing dataset...")
    dataset = LDABERT2Dataset(dataset_type=dataset_type,
                            pct_data=pct_data,
                          max_seq_length=max_sentence_length,
                            max_segment_length=5,
                            augment_pct=augment_pct,
                            split="train")
    
    # process dataset
    print("processing dataset...")
    sentences, tokenized_sentences, labels = dataset.process()

    vectors_path = '../../data/lda_bert_2/{}/{}_{}.pkl'.format(dataset_type, 
                                                            dataset.pct_data, 
                                                            dataset.augment_pct)

    saved_vectors, saved_labels, saved_sentences, saved_tokenized_sentences = dataset.get_saved_vectors(vectors_path)

    if len(saved_vectors) == 0:
        saved_vectors, saved_labels, saved_sentences, saved_tokenized_sentences = dataset.create_vectors(vectors_path)

    left_input, mid_input, right_input = dataset.format_sentences_tri_input_plus(saved_tokenized_sentences)
    lda_left_input, lda_mid_input, lda_right_input = dataset.format_sentences_tri_input(saved_vectors)

    # get class weight
    neg, pos = np.bincount(labels.flatten())
    initial_bias = np.log([pos/neg])
    
    total=len(labels)
    weight_for_0 = (1 / neg)*(total)/2.0 
    weight_for_1 = (1 / pos)*(total)/2.0

    class_weight = {0: weight_for_0, 1: weight_for_1}
    print("class weight", class_weight)
    
    # create checkpoint path
    checkpoint_filepath = '{}/models/LDABERT2/simple/{}-{}-{}-pct-{}-aug_{}/finetune/checkpoint.ckpt'.format(
                            config.root_path,
                            dataset.dataset_type,                    
                            len(saved_sentences), 
                            dataset.pct_data,
                            dataset.augment_pct,
                            random_hash)
    
    # continue training
    checkpoint_filepath = '{}/models/LDABERT2/simple/clinical-16122-1-pct-1-aug_288O6/finetune/checkpoint.ckpt'.format(config.root_path)
    
    print(checkpoint_filepath)
    
    # get callbacks ready.
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        save_best_only=True,
        mode="auto",
        save_freq="epoch")

    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', 
        verbose=1,
        patience=10,
        mode='max',
        restore_best_weights=True)

    callbacks = [
    #     early_stopping,
        model_checkpoint_callback
    ]
    
    # compiling model
    print("compiling the model...")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  metrics=[
                      keras.metrics.BinaryAccuracy(name='accuracy')
                  ])
    
    try:
        model.load_weights(checkpoint_filepath)
        print("model loaded.")
    except:
        print("No checkpoint available.")
    
    print("starting the training process...")
    history = model.fit([
                            left_input, mid_input, right_input, 
                            lda_left_input, lda_mid_input, lda_right_input
                        ], 
                        tf.convert_to_tensor(saved_labels), 
                        epochs=epochs,
                        validation_split=0.25,
                        batch_size=BATCH_SIZE,
                        verbose=1, 
                        class_weight=class_weight,
                        callbacks=callbacks)
    
    # assigning history to experiment object for saving.
    experiment["history"] = history.history
    experiment["hash"] = random_hash
    
    print("saving results...")    
    save_results(experiment)
# Out:
# params: {'bert_type': 'ldabert', 'dataset_type': 'clinical', 'final_dropout': 0.5, 'dense_neurons': 128, 'max_sentence_length': 128, 'gamma': 15, 'pct_data': 1, 'augment_pct': 1, 'bert_trainable': True, 'epochs': 50}
# initializing model...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=625.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=438007537.0, style=ProgressStyle(descri…
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# initializing dataset...
# processing dataset...
# class weight {0: 0.6363521055301877, 1: 2.3334883720930235}
# /content/drive/MyDrive/SCHOOL/PhD/Code/context-encoder-v2/models/LDABERT2/simple/clinical-16122-1-pct-1-aug_288O6/finetune/checkpoint.ckpt
# compiling the model...
# model loaded.
# starting the training process...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/300
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f35e5f4dd70>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f35e5f4dd70>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7f3611100170> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7f3611100170> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 1512/1512 [==============================] - ETA: 0s - loss: 0.7029 - accuracy: 0.5316WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 1512/1512 [==============================] - 706s 424ms/step - loss: 0.7029 - accuracy: 0.5316 - val_loss: 0.6606 - val_accuracy: 0.6165
# Epoch 2/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6992 - accuracy: 0.5325 - val_loss: 0.7318 - val_accuracy: 0.4334
# Epoch 3/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6979 - accuracy: 0.5389 - val_loss: 0.6753 - val_accuracy: 0.5765
# Epoch 4/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6963 - accuracy: 0.5416 - val_loss: 0.6863 - val_accuracy: 0.5413
# Epoch 5/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6933 - accuracy: 0.5549 - val_loss: 0.7008 - val_accuracy: 0.5088
# Epoch 6/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6943 - accuracy: 0.5492 - val_loss: 0.6428 - val_accuracy: 0.6678
# Epoch 7/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6912 - accuracy: 0.5531 - val_loss: 0.6216 - val_accuracy: 0.6812
# Epoch 8/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6905 - accuracy: 0.5600 - val_loss: 0.7041 - val_accuracy: 0.5078
# Epoch 9/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6881 - accuracy: 0.5652 - val_loss: 0.6805 - val_accuracy: 0.5631
# Epoch 10/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6882 - accuracy: 0.5632 - val_loss: 0.6295 - val_accuracy: 0.6626
# Epoch 11/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6851 - accuracy: 0.5697 - val_loss: 0.6254 - val_accuracy: 0.6713
# Epoch 12/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6828 - accuracy: 0.5685 - val_loss: 0.6183 - val_accuracy: 0.6777
# Epoch 13/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6818 - accuracy: 0.5759 - val_loss: 0.6503 - val_accuracy: 0.6194
# Epoch 14/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6751 - accuracy: 0.5789 - val_loss: 0.6078 - val_accuracy: 0.6926
# Epoch 15/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6796 - accuracy: 0.5818 - val_loss: 0.7136 - val_accuracy: 0.5123
# Epoch 16/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6768 - accuracy: 0.5816 - val_loss: 0.6436 - val_accuracy: 0.6266
# Epoch 17/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6746 - accuracy: 0.5825 - val_loss: 0.5572 - val_accuracy: 0.7554
# Epoch 18/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6726 - accuracy: 0.5931 - val_loss: 0.5881 - val_accuracy: 0.7187
# Epoch 19/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6704 - accuracy: 0.5918 - val_loss: 0.6280 - val_accuracy: 0.6559
# Epoch 20/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6702 - accuracy: 0.5942 - val_loss: 0.6355 - val_accuracy: 0.6452
# Epoch 21/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6691 - accuracy: 0.5936 - val_loss: 0.6657 - val_accuracy: 0.5956
# Epoch 22/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6640 - accuracy: 0.6001 - val_loss: 0.6754 - val_accuracy: 0.5825
# Epoch 23/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6695 - accuracy: 0.5991 - val_loss: 0.6074 - val_accuracy: 0.6777
# Epoch 24/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6605 - accuracy: 0.6100 - val_loss: 0.5877 - val_accuracy: 0.7048
# Epoch 25/300
# 1512/1512 [==============================] - 639s 422ms/step - loss: 0.6653 - accuracy: 0.6020 - val_loss: 0.6457 - val_accuracy: 0.6192
# Epoch 26/300
# 1512/1512 [==============================] - 639s 422ms/step - loss: 0.6649 - accuracy: 0.6001 - val_loss: 0.6600 - val_accuracy: 0.6021
# Epoch 27/300
# 1512/1512 [==============================] - 639s 422ms/step - loss: 0.6651 - accuracy: 0.6079 - val_loss: 0.6070 - val_accuracy: 0.6802
# Epoch 28/300
# 1512/1512 [==============================] - 639s 422ms/step - loss: 0.6628 - accuracy: 0.6051 - val_loss: 0.5598 - val_accuracy: 0.7415
# Epoch 29/300
# 1512/1512 [==============================] - 639s 422ms/step - loss: 0.6618 - accuracy: 0.6100 - val_loss: 0.6494 - val_accuracy: 0.6160
# Epoch 30/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6615 - accuracy: 0.6061 - val_loss: 0.6185 - val_accuracy: 0.6614
# Epoch 31/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6657 - accuracy: 0.6000 - val_loss: 0.6251 - val_accuracy: 0.6537
# Epoch 32/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6627 - accuracy: 0.6111 - val_loss: 0.6384 - val_accuracy: 0.6358
# Epoch 33/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6601 - accuracy: 0.6062 - val_loss: 0.5976 - val_accuracy: 0.6802
# Epoch 34/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6607 - accuracy: 0.6154 - val_loss: 0.6748 - val_accuracy: 0.5832
# Epoch 35/300
# 1512/1512 [==============================] - 636s 421ms/step - loss: 0.6570 - accuracy: 0.6134 - val_loss: 0.6018 - val_accuracy: 0.6827
# Epoch 36/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6600 - accuracy: 0.6161 - val_loss: 0.6495 - val_accuracy: 0.6182
# Epoch 37/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6569 - accuracy: 0.6139 - val_loss: 0.6021 - val_accuracy: 0.6877
# Epoch 38/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6575 - accuracy: 0.6181 - val_loss: 0.6325 - val_accuracy: 0.6393
# Epoch 39/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6600 - accuracy: 0.6165 - val_loss: 0.7009 - val_accuracy: 0.5557
# Epoch 40/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6553 - accuracy: 0.6128 - val_loss: 0.5972 - val_accuracy: 0.6894
# Epoch 41/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6556 - accuracy: 0.6167 - val_loss: 0.5661 - val_accuracy: 0.7147
# Epoch 42/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6586 - accuracy: 0.6151 - val_loss: 0.5872 - val_accuracy: 0.6954
# Epoch 43/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6604 - accuracy: 0.6102 - val_loss: 0.6232 - val_accuracy: 0.6539
# Epoch 44/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6567 - accuracy: 0.6181 - val_loss: 0.6724 - val_accuracy: 0.5884
# Epoch 45/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6610 - accuracy: 0.6066 - val_loss: 0.5545 - val_accuracy: 0.7462
# Epoch 46/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6558 - accuracy: 0.6169 - val_loss: 0.5900 - val_accuracy: 0.6949
# Epoch 47/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6544 - accuracy: 0.6186 - val_loss: 0.5870 - val_accuracy: 0.7001
# Epoch 48/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6550 - accuracy: 0.6153 - val_loss: 0.6000 - val_accuracy: 0.6889
# Epoch 49/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6574 - accuracy: 0.6127 - val_loss: 0.6574 - val_accuracy: 0.6118
# Epoch 50/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6565 - accuracy: 0.6137 - val_loss: 0.6031 - val_accuracy: 0.6763
# Epoch 51/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6539 - accuracy: 0.6189 - val_loss: 0.6958 - val_accuracy: 0.5569
# Epoch 52/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6568 - accuracy: 0.6161 - val_loss: 0.5896 - val_accuracy: 0.7040
# Epoch 53/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6540 - accuracy: 0.6210 - val_loss: 0.6063 - val_accuracy: 0.6787
# Epoch 54/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6574 - accuracy: 0.6173 - val_loss: 0.6087 - val_accuracy: 0.6658
# Epoch 55/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6487 - accuracy: 0.6241 - val_loss: 0.6831 - val_accuracy: 0.5696
# Epoch 56/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6545 - accuracy: 0.6181 - val_loss: 0.5840 - val_accuracy: 0.7132
# Epoch 57/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6498 - accuracy: 0.6234 - val_loss: 0.6101 - val_accuracy: 0.6735
# Epoch 58/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6541 - accuracy: 0.6140 - val_loss: 0.5823 - val_accuracy: 0.6993
# Epoch 59/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6500 - accuracy: 0.6272 - val_loss: 0.6437 - val_accuracy: 0.6301
# Epoch 60/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6495 - accuracy: 0.6172 - val_loss: 0.5632 - val_accuracy: 0.7222
# Epoch 61/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6506 - accuracy: 0.6295 - val_loss: 0.6036 - val_accuracy: 0.6830
# Epoch 62/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6497 - accuracy: 0.6239 - val_loss: 0.6631 - val_accuracy: 0.6073
# Epoch 63/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6516 - accuracy: 0.6210 - val_loss: 0.6463 - val_accuracy: 0.6219
# Epoch 64/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6556 - accuracy: 0.6133 - val_loss: 0.6324 - val_accuracy: 0.6408
# Epoch 65/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6473 - accuracy: 0.6271 - val_loss: 0.6998 - val_accuracy: 0.5604
# Epoch 66/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6520 - accuracy: 0.6187 - val_loss: 0.5953 - val_accuracy: 0.6797
# Epoch 67/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6468 - accuracy: 0.6329 - val_loss: 0.6644 - val_accuracy: 0.6028
# Epoch 68/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6482 - accuracy: 0.6265 - val_loss: 0.6976 - val_accuracy: 0.5696
# Epoch 69/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6498 - accuracy: 0.6184 - val_loss: 0.5711 - val_accuracy: 0.7184
# Epoch 70/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6462 - accuracy: 0.6335 - val_loss: 0.6353 - val_accuracy: 0.6425
# Epoch 71/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6526 - accuracy: 0.6252 - val_loss: 0.5929 - val_accuracy: 0.6941
# Epoch 72/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6460 - accuracy: 0.6290 - val_loss: 0.6348 - val_accuracy: 0.6433
# Epoch 73/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6474 - accuracy: 0.6306 - val_loss: 0.6358 - val_accuracy: 0.6341
# Epoch 74/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6486 - accuracy: 0.6269 - val_loss: 0.5875 - val_accuracy: 0.6973
# Epoch 75/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6473 - accuracy: 0.6301 - val_loss: 0.6483 - val_accuracy: 0.6242
# Epoch 76/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6483 - accuracy: 0.6266 - val_loss: 0.5633 - val_accuracy: 0.7276
# Epoch 77/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6452 - accuracy: 0.6286 - val_loss: 0.5088 - val_accuracy: 0.7733
# Epoch 78/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6482 - accuracy: 0.6275 - val_loss: 0.6331 - val_accuracy: 0.6438
# Epoch 79/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6418 - accuracy: 0.6368 - val_loss: 0.6107 - val_accuracy: 0.6730
# Epoch 80/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6475 - accuracy: 0.6340 - val_loss: 0.6356 - val_accuracy: 0.6418
# Epoch 81/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6454 - accuracy: 0.6317 - val_loss: 0.6095 - val_accuracy: 0.6668
# Epoch 82/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6440 - accuracy: 0.6322 - val_loss: 0.6685 - val_accuracy: 0.5971
# Epoch 83/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6444 - accuracy: 0.6310 - val_loss: 0.6714 - val_accuracy: 0.5979
# Epoch 84/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6508 - accuracy: 0.6233 - val_loss: 0.5898 - val_accuracy: 0.6956
# Epoch 85/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6455 - accuracy: 0.6337 - val_loss: 0.6553 - val_accuracy: 0.6190
# Epoch 86/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6468 - accuracy: 0.6263 - val_loss: 0.5735 - val_accuracy: 0.7107
# Epoch 87/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6463 - accuracy: 0.6335 - val_loss: 0.6218 - val_accuracy: 0.6532
# Epoch 88/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6437 - accuracy: 0.6337 - val_loss: 0.5637 - val_accuracy: 0.7162
# Epoch 89/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6475 - accuracy: 0.6287 - val_loss: 0.6089 - val_accuracy: 0.6775
# Epoch 90/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6419 - accuracy: 0.6325 - val_loss: 0.6967 - val_accuracy: 0.5696
# Epoch 91/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6446 - accuracy: 0.6267 - val_loss: 0.6086 - val_accuracy: 0.6703
# Epoch 92/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6434 - accuracy: 0.6331 - val_loss: 0.6101 - val_accuracy: 0.6698
# Epoch 93/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6454 - accuracy: 0.6306 - val_loss: 0.5736 - val_accuracy: 0.7075
# Epoch 94/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6432 - accuracy: 0.6334 - val_loss: 0.6192 - val_accuracy: 0.6671
# Epoch 95/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6464 - accuracy: 0.6341 - val_loss: 0.6079 - val_accuracy: 0.6743
# Epoch 96/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6472 - accuracy: 0.6300 - val_loss: 0.6631 - val_accuracy: 0.6088
# Epoch 97/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6446 - accuracy: 0.6299 - val_loss: 0.6378 - val_accuracy: 0.6381
# Epoch 98/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6446 - accuracy: 0.6355 - val_loss: 0.6183 - val_accuracy: 0.6596
# Epoch 99/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6381 - accuracy: 0.6401 - val_loss: 0.6062 - val_accuracy: 0.6755
# Epoch 100/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6444 - accuracy: 0.6322 - val_loss: 0.6204 - val_accuracy: 0.6547
# Epoch 101/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6394 - accuracy: 0.6382 - val_loss: 0.6759 - val_accuracy: 0.5932
# Epoch 102/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6403 - accuracy: 0.6379 - val_loss: 0.5954 - val_accuracy: 0.6884
# Epoch 103/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6432 - accuracy: 0.6367 - val_loss: 0.5889 - val_accuracy: 0.7001
# Epoch 104/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6430 - accuracy: 0.6297 - val_loss: 0.6333 - val_accuracy: 0.6460
# Epoch 105/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6440 - accuracy: 0.6353 - val_loss: 0.7072 - val_accuracy: 0.5445
# Epoch 106/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6426 - accuracy: 0.6374 - val_loss: 0.6948 - val_accuracy: 0.5748
# Epoch 107/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6392 - accuracy: 0.6356 - val_loss: 0.5788 - val_accuracy: 0.7068
# Epoch 108/300
# 1512/1512 [==============================] - 638s 422ms/step - loss: 0.6414 - accuracy: 0.6399 - val_loss: 0.6704 - val_accuracy: 0.6103
# Epoch 109/300
# 1512/1512 [==============================] - 637s 422ms/step - loss: 0.6413 - accuracy: 0.6321 - val_loss: 0.5841 - val_accuracy: 0.7016
# Epoch 110/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6445 - accuracy: 0.6327 - val_loss: 0.6187 - val_accuracy: 0.6579
# Epoch 111/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6436 - accuracy: 0.6258 - val_loss: 0.6130 - val_accuracy: 0.6653
# Epoch 112/300
# 1512/1512 [==============================] - 637s 421ms/step - loss: 0.6409 - accuracy: 0.6365 - val_loss: 0.6855 - val_accuracy: 0.5758
# Epoch 113/300
# 1512/1512 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.6350

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d7a4aa83693> in <module>()
#       1 from matplotlib import pyplot as plt
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined
